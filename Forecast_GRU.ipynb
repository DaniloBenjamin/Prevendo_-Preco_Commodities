# %% [markdown]
# ### <font color='blue'>Prevendo a Relação do Preço de Commodities e Mudanças Climáticas ao Longo do Tempo</font>
# ### <font color='blue'>Gated Recurrent Units (GRUs)</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# !pip install -q tensorflow==2.11.0

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error, explained_variance_score
import matplotlib.dates as mdates
plt.rcParams['figure.figsize'] = (10, 5)
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Carregando os Dados

# %%
df = pd.read_csv('dados/dataset.csv')

# %%
df.shape
# Out:
# (124, 12)

# %%
df.head()
# Out:
#          data  petroleo_bruto  minerio_ferro     ouro   arroz  feijao  milho  \
# 0  2012-12-01             323            455  3102.61  423.45   844.0  468.0
# 1  2013-01-01             345            546  3100.45  415.85   799.0  485.0
# 2  2013-02-01             362            595  3199.41  410.77   718.0  466.0
# 3  2013-03-01             376            636  3281.67  414.82   614.0  442.0
# 4  2013-04-01             383            738  3261.65  451.04   619.0  429.0
#
#     soja  trigo       cafe  algodao    umidade
# 0  578.0  28.67  207.70504    117.7  79.261905
# 1  557.0  24.49  228.94287      4.5  82.193548
# 2  552.0  22.06  238.41747     25.1  74.839286
# 3  574.0  21.64  218.47599     53.6  77.935484
# 4  595.0  22.30  226.15010    166.0  80.450000

# %%
# Converte a coluna de data em índice
df.index = pd.to_datetime(df['data'], format = '%Y.%m.%d')

# %%
del df['data']

# %%
df.head()
# Out:
#             petroleo_bruto  minerio_ferro     ouro   arroz  feijao  milho  \
# data
# 2012-12-01             323            455  3102.61  423.45   844.0  468.0
# 2013-01-01             345            546  3100.45  415.85   799.0  485.0
# 2013-02-01             362            595  3199.41  410.77   718.0  466.0
# 2013-03-01             376            636  3281.67  414.82   614.0  442.0
# 2013-04-01             383            738  3261.65  451.04   619.0  429.0
#
#              soja  trigo       cafe  algodao    umidade
# data
# 2012-12-01  578.0  28.67  207.70504    117.7  79.261905
# 2013-01-01  557.0  24.49  228.94287      4.5  82.193548
# 2013-02-01  552.0  22.06  238.41747     25.1  74.839286
# 2013-03-01  574.0  21.64  218.47599     53.6  77.935484
# 2013-04-01  595.0  22.30  226.15010    166.0  80.450000

# %%
# Plot
plt.figure(figsize = (20,5))
plt.grid()
plt.plot(df.index, df['petroleo_bruto'], color = 'blue')
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval = 12))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%Y'))
plt.gcf().autofmt_xdate() 
plt.legend(['Cotação'], loc='best')
plt.title('Cotação do Petróleo Bruto Entre 2012-2023\n')
plt.ylabel('\nCotação do Petróleo Bruto')
plt.xlabel('\nData')
# Out:
# Text(0.5, 0, '\nData')

# %% [markdown]
# ## Arquitetura Gated Recurrent Units (GRUs)
#
# Leia o manual em pdf no Capítulo 5.

# %% [markdown]
# ### Pré-Processamento dos Dados

# %%
# Proporção de dados para treino e teste
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size

# %%
# Define o tamanho das amostras
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]

# %%
print('Tamanho da Amostra de Treino:', len(train))
print('Tamanho da Amostra de Teste:', len(test))
# Out:
# Tamanho da Amostra de Treino: 99
# Tamanho da Amostra de Teste: 25

# %%
print(train.shape)
train.head()
# Out:
# (99, 11)
#             petroleo_bruto  minerio_ferro     ouro   arroz  feijao  milho  \
# data
# 2012-12-01             323            455  3102.61  423.45   844.0  468.0
# 2013-01-01             345            546  3100.45  415.85   799.0  485.0
# 2013-02-01             362            595  3199.41  410.77   718.0  466.0
# 2013-03-01             376            636  3281.67  414.82   614.0  442.0
# 2013-04-01             383            738  3261.65  451.04   619.0  429.0
#
#              soja  trigo       cafe  algodao    umidade
# data
# 2012-12-01  578.0  28.67  207.70504    117.7  79.261905
# 2013-01-01  557.0  24.49  228.94287      4.5  82.193548
# 2013-02-01  552.0  22.06  238.41747     25.1  74.839286
# 2013-03-01  574.0  21.64  218.47599     53.6  77.935484
# 2013-04-01  595.0  22.30  226.15010    166.0  80.450000

# %%
# Variáveis preditoras
variaveis_preditoras = ['minerio_ferro', 
                        'ouro', 
                        'arroz', 
                        'feijao', 
                        'milho', 
                        'soja', 
                        'trigo', 
                        'cafe', 
                        'algodao', 
                        'umidade']

# %%
# Prepara o padronizador das variáveis preditoras
scaler_preditores = MinMaxScaler()

# %%
# Fit nos dados de treino
scaler_preditores = scaler_preditores.fit(train[variaveis_preditoras].to_numpy())

# %%
# Transform nos dados de treino
train.loc[:, variaveis_preditoras] = scaler_preditores.transform(train[variaveis_preditoras].to_numpy())

# %%
train.head()
# Out:
#             petroleo_bruto  minerio_ferro      ouro     arroz    feijao  \
# data
# 2012-12-01             323       0.112288  0.140918  0.010736  0.528090
# 2013-01-01             345       0.305085  0.140327  0.004301  0.443820
# 2013-02-01             362       0.408898  0.167408  0.000000  0.292135
# 2013-03-01             376       0.495763  0.189919  0.003429  0.097378
# 2013-04-01             383       0.711864  0.184440  0.034095  0.106742
#
#                milho      soja     trigo      cafe   algodao   umidade
# data
# 2012-12-01  0.253193  0.023302  0.109026  0.617026  0.366984  0.843364
# 2013-01-01  0.306536  0.009321  0.044200  0.815738  0.007619  0.983088
# 2013-02-01  0.246917  0.005992  0.006514  0.904388  0.073016  0.632580
# 2013-03-01  0.171609  0.020639  0.000000  0.717805  0.163492  0.780147
# 2013-04-01  0.130817  0.034621  0.010236  0.789608  0.520317  0.899990

# %%
# Transform nos dados de teste
test.loc[:, variaveis_preditoras] = scaler_preditores.transform(test[variaveis_preditoras].to_numpy())

# %%
test.head()
# Out:
#             petroleo_bruto  minerio_ferro      ouro     arroz    feijao  \
# data
# 2021-03-01             354       0.637712  0.194855  0.382454  0.381292
# 2021-04-01             348       0.533898  0.264388  0.393951  0.213633
# 2021-05-01             332       0.400424  0.246417  0.453802  0.235262
# 2021-06-01             349       0.317797  0.234308  0.509834  0.320749
# 2021-07-01             372       0.313559  0.223422  0.526454  0.426610
#
#                milho      soja     trigo      cafe   algodao   umidade
# data
# 2021-03-01 -0.039662  0.493342  0.455180  0.707023  0.548889  0.265874
# 2021-04-01 -0.054975  0.597870  0.515974  0.732180  0.017143  0.437683
# 2021-05-01 -0.092159  0.606525  0.530397  0.708895  0.444127  0.349664
# 2021-06-01 -0.074743  0.631824  0.593207  0.808476  0.181905  0.645800
# 2021-07-01 -0.066114  0.773462  0.641749  0.866202  0.436825  0.577974

# %%
# Padronizador da variável alvo
scaler_target = MinMaxScaler()

# %%
# Fit nos dados de treino
scaler_target = scaler_target.fit(train[['petroleo_bruto']])

# %%
# Transform nos dados de treino
train['petroleo_bruto'] = scaler_target.transform(train[['petroleo_bruto']])

# %%
train['petroleo_bruto'].head()
# Out:
# data
# 2012-12-01    0.0100
# 2013-01-01    0.0650
# 2013-02-01    0.1075
# 2013-03-01    0.1425
# 2013-04-01    0.1600
# Name: petroleo_bruto, dtype: float64

# %%
# Transform nos dados de teste
test['petroleo_bruto'] = scaler_target.transform(test[['petroleo_bruto']])

# %%
test['petroleo_bruto'].head()
# Out:
# data
# 2021-03-01    0.0875
# 2021-04-01    0.0725
# 2021-05-01    0.0325
# 2021-06-01    0.0750
# 2021-07-01    0.1325
# Name: petroleo_bruto, dtype: float64

# %%
# Função para criar o dataset final
def createDataset(X, y, time_steps):
    
    Xs, ys = [], []
    
    for i in range(len(X) - time_steps):
        data = X.iloc[i:(i + time_steps)].values
        Xs.append(data)        
        ys.append(y.iloc[i + time_steps])
        
    return np.array(Xs), np.array(ys)

# %%
time_steps = 3

# %%
X_train, y_train = createDataset(train, train.petroleo_bruto, time_steps)

# %%
X_test, y_test = createDataset(test, test.petroleo_bruto, time_steps)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (96, 3, 11) (96,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (22, 3, 11) (22,)

# %% [markdown]
# ## Modelagem com GRU

# %%
# Cria o modelo
modelo_gru = tf.keras.Sequential()
modelo_gru.add(tf.keras.layers.GRU(units = 128, input_shape = (X_train.shape[1], X_train.shape[2])))
modelo_gru.add(tf.keras.layers.Dropout(rate = 0.2))
modelo_gru.add(tf.keras.layers.Dense(units = 1))

# %%
# Compila o modelo
modelo_gru.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
modelo_gru.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 128)               54144
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 54,273
# Trainable params: 54,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Treinamento do Modelo

# %%
# %%time
modelo_gru_history = modelo_gru.fit(X_train, 
                                    y_train,
                                    epochs = 100,
                                    batch_size = 32,
                                    validation_split = 0.1,
                                    shuffle = False)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 156ms/step - loss: 0.2636 - val_loss: 0.0343
# Epoch 2/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0627 - val_loss: 0.1146
# Epoch 3/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0594 - val_loss: 0.2146
# Epoch 4/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0915 - val_loss: 0.2160
# Epoch 5/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0885 - val_loss: 0.1469
# Epoch 6/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0552 - val_loss: 0.0855
# Epoch 7/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0392 - val_loss: 0.0524
# Epoch 8/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0386 - val_loss: 0.0405
# Epoch 9/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0482 - val_loss: 0.0411
# Epoch 10/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0305 - val_loss: 0.0493
# Epoch 11/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0272 - val_loss: 0.0602
# Epoch 12/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0237 - val_loss: 0.0651
# Epoch 13/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0239 - val_loss: 0.0586
# Epoch 14/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0250 - val_loss: 0.0473
# Epoch 15/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0227 - val_loss: 0.0363
# Epoch 16/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0212 - val_loss: 0.0294
# Epoch 17/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0238 - val_loss: 0.0266
# Epoch 18/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0210 - val_loss: 0.0290
# Epoch 19/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0226 - val_loss: 0.0314
# Epoch 20/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0313
# Epoch 21/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0180 - val_loss: 0.0263
# Epoch 22/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 23/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0157 - val_loss: 0.0149
# Epoch 24/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0149 - val_loss: 0.0147
# Epoch 25/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0162 - val_loss: 0.0165
# Epoch 26/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0153 - val_loss: 0.0185
# Epoch 27/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0182
# Epoch 28/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0174 - val_loss: 0.0167
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0131 - val_loss: 0.0151
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 31/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0135 - val_loss: 0.0153
# Epoch 32/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0118 - val_loss: 0.0170
# Epoch 33/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0144 - val_loss: 0.0184
# Epoch 34/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0136 - val_loss: 0.0180
# Epoch 35/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0171
# Epoch 36/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0126 - val_loss: 0.0183
# Epoch 37/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0130 - val_loss: 0.0186
# Epoch 38/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0115 - val_loss: 0.0174
# Epoch 39/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0145 - val_loss: 0.0173
# Epoch 40/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0170
# Epoch 41/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0134 - val_loss: 0.0171
# Epoch 42/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0161
# Epoch 43/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0180
# Epoch 44/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0110 - val_loss: 0.0208
# Epoch 45/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0245
# Epoch 46/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0263
# Epoch 47/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0216
# Epoch 48/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0162
# Epoch 49/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0160 - val_loss: 0.0149
# Epoch 50/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0180
# Epoch 51/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0230
# Epoch 52/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0103 - val_loss: 0.0262
# Epoch 53/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0230
# Epoch 54/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0172
# Epoch 55/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0149
# Epoch 56/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0189
# Epoch 57/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0249
# Epoch 58/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0203
# Epoch 59/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0151
# Epoch 60/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0112 - val_loss: 0.0148
# Epoch 61/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0115 - val_loss: 0.0171
# Epoch 62/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0189
# Epoch 63/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0220
# Epoch 64/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0231
# Epoch 65/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0178
# Epoch 66/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0151
# Epoch 67/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0155
# Epoch 68/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0186
# Epoch 69/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0219
# Epoch 70/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0220
# Epoch 71/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0192
# Epoch 72/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0173
# Epoch 73/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0112 - val_loss: 0.0161
# Epoch 74/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0186
# Epoch 75/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0110 - val_loss: 0.0212
# Epoch 76/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0216
# Epoch 77/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0187
# Epoch 78/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0106 - val_loss: 0.0179
# Epoch 79/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0090 - val_loss: 0.0202
# Epoch 80/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0206
# Epoch 81/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0199
# Epoch 82/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0192
# Epoch 83/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0199
# Epoch 84/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0115 - val_loss: 0.0210
# Epoch 85/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0212
# Epoch 86/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0217
# Epoch 87/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0189
# Epoch 88/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0161
# Epoch 89/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0184
# Epoch 90/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0221
# Epoch 91/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0212
# Epoch 92/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0172
# Epoch 93/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0156
# Epoch 94/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0173
# Epoch 95/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0225
# Epoch 96/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0224
# Epoch 97/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0173
# Epoch 98/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0182
# Epoch 99/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0197
# Epoch 100/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0090 - val_loss: 0.0187
# CPU times: user 4.38 s, sys: 379 ms, total: 4.76 s
# Wall time: 3.81 s

# %%
# Plot
plt.plot(modelo_gru_history.history['loss'])
plt.plot(modelo_gru_history.history['val_loss'])
plt.title('Avaliação do Modelo')
plt.ylabel('Erro')
plt.xlabel('Epoch')
plt.legend(['Treino', 'Validação'], loc = 'upper right')
plt.show()

# %% [markdown]
# ### Previsões com Dados de Teste

# %%
y_pred = modelo_gru.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 148ms/step

# %%
y_pred
# Out:
# array([[ 0.0738361 ],
#        [ 0.09710331],
#        [ 0.11586973],
#        [ 0.10505959],
#        [ 0.03401877],
#        [ 0.01363758],
#        [ 0.00112563],
#        [ 0.00536294],
#        [-0.02735735],
#        [-0.05408844],
#        [-0.08068387],
#        [-0.07184647],
#        [-0.04464392],
#        [-0.01789468],
#        [ 0.00710016],
#        [-0.01706241],
#        [-0.07088247],
#        [-0.03870064],
#        [ 0.10151878],
#        [ 0.16878252],
#        [ 0.13809781],
#        [ 0.07775706]], dtype=float32)

# %% [markdown]
# ### Invertendo a Escala

# %%
# Invertemos a escala para visualizar o valor real e a previsão
y_train_inv = scaler_target.inverse_transform(y_train.reshape(1, -1))
y_test_inv = scaler_target.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = scaler_target.inverse_transform(y_pred.reshape(1,-1))

# %%
# Ajusta o shape
y_train_inv = y_train_inv.flatten()
y_test_inv = y_test_inv.flatten()
y_pred_inv = y_pred_inv.flatten()

# %% [markdown]
# ### Plot

# %%
# Plot
plt.plot(np.arange(0, len(y_train)), 
         y_train_inv, 
         color = 'green', 
         label = "Histórico")

plt.plot(np.arange(len(y_train), 
                   len(y_train) + len(y_test)), 
         y_test_inv, 
         color = 'blue', 
         marker = '.', 
         label = "Valor Real")

plt.plot(np.arange(len(y_train), 
                   len(y_train) + len(y_test)), 
         y_pred_inv, 
         color = 'red', 
         label = "Previsão")

plt.ylabel('Cotação do Petróleo')
plt.xlabel('Data')
plt.legend()
plt.show();

# %%
# Plot apenas do valor real x valor previsto
plt.plot(y_test_inv, marker = '.', label = "Valor Real")
plt.plot(y_pred_inv, color = 'red', label = "Valor Previsto")
plt.ylabel('Cotação do Petróleo Bruto')
plt.xlabel('Tempo')
plt.legend()
plt.show();

# %% [markdown]
# ### Avaliação

# %%
# Mean Directional Accuracy
def mda(actual: np.ndarray, predicted: np.ndarray):
    return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - predicted[:-1])).astype(int))

# %%
# Imprime as métricas

MDA_gru = mda(y_test_inv, y_pred_inv)
print('MDA:', MDA_gru)

MAE_gru = mean_absolute_error(y_test_inv, y_pred_inv)
print('MAE:', MAE_gru)

MSE_gru = mean_squared_error(y_test_inv, y_pred_inv)
print('MSE:', MSE_gru)

RMSE_gru = mean_squared_error(y_test_inv, y_pred_inv, squared = False)
print('RMSE:', RMSE_gru)

EVS_gru = explained_variance_score(y_test_inv, y_pred_inv)
print('EVS Score:', EVS_gru)
# Out:
# MDA: 0.38095238095238093
# MAE: 44.37059992009943
# MSE: 2566.5752220312975
# RMSE: 50.66137801157108
# EVS Score: 0.18420658574185989

# %%
# Salva o modelo
def save_model(model):
    json_model = model.to_json()
    open('modelos/modelo_gru.json', 'w').write(json_model)
    model.save_weights('modelos/modelo_gru.h5', overwrite = True)

# %%
save_model(modelo_gru)
